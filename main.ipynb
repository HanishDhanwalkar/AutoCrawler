# %%
import os
from dotenv import load_dotenv

load_dotenv()

load_dotenv('.env')
APIKEY = os.getenv('API_KEY')

# %%
import google.generativeai as genai

genai.configure(api_key=APIKEY)
model = genai.GenerativeModel('gemini-pro')

# %%
response = model.generate_content("Hi")
print(response.text)
# Out:
# Hello there! How can I assist you today?

# %%
def xpath_finder(htmlcode, instructions):
    prompt = f'''
        You're a web parser that is good at reading and understanding the HTML code and can give clear executable code on the brower.
        Please read the following HTML code, and then return an Xpath that can recognize the element in the HTML matching the instruction below.
        Instructions:
        {instructions}\n

        Here the HTML code:
        ```
        {htmlcode}
        ```
        If the HTML code doesn't contain the suitable information match the instruction, keep the xpath attrs blank.
        '''
    
    res = model.generate_content(prompt)
    return res.text

def selector_promter(htmlcode, instructions):
    prompt = f'''
        Please read the following HTML code, and then return an CSS selector that can recognize the element in the HTML matching the instruction below.
        Instructions:
        {instructions}

        Here the HTML code:
        ```
        {htmlcode}
        ```
        If the HTML code doesn't contain the suitable information match the instruction, keep blank string.
    '''
    res = model.generate_content(prompt)
    return res.text

def coder(htmlcode, instructions):
    selector = selector_promter(htmlcode, instructions)
    prompt = f'''
        Please read the following HTML code, and then return an python code that can recognize the element in the HTML matching the instruction below.
        Instructions:
            1. Code to scrape based on selector '{selector}'
            2. Import the package you need to use
            3. Define the extraction code as a function called 'extract_value', with one parameters 'HTML', so that we can input html with the parameters. The output of the function is the extraction result.
            4. Don't generate other parts of the code
        
        Here the HTML code:
        ```
        {htmlcode}
        ```
        If the HTML code doesn't contain the suitable information match the instruction, keep blank string.
    '''
    res = model.generate_content(prompt)
    return res.text

# %%
html = """
  <html>
    <body>
      <div class="product-info">
        <h1>Product Name</h1>
        <p>Price: $100</p>
      </div>
    </body>
  </html>
"""

# print(xpath_finder(html, "price"))
# print(selector_promter(html, "price"))
print(coder(html, "price"))
# Out:
# ```python
# import bs4
#
# def extract_value(html):
#     soup = bs4.BeautifulSoup(html, features="html.parser")
#     element = soup.select('.product-info p')
#     if element:
#         return element[-1].text
#     else:
#         return ""
# ```

# %%
import bs4
from bs4 import BeautifulSoup

def extract_value(HTML):
    soup = BeautifulSoup(HTML, 'html.parser')
    return soup.select_one('.product-info p').text

extract_value(html)
# Out:
# 'Price: $100'

# %%
def main(website_path):
    with open(website_path, 'r', errors='ignore') as f:
        html = f.read()
    # print(html)
    print(coder(html[50:500], "Extract Movie name"))

main(r"data\movie\0000.htm")
# Out:
# ```python
# import bs4
# def extract_value(html):
#     soup = bs4.BeautifulSoup(html, 'html.parser')
#     return soup.title.string.strip()
# ```

# %%
# generated code
def extract_value(HTML):
    # Create a BeautifulSoup object from the HTML
    soup = bs4.BeautifulSoup(HTML, "html.parser")

    # Find the title element
    title = soup.find("title")

    # If the title element was found, return its text content
    if title:
        return title.text

    # If the title element was not found, return an empty string
    else:
        return ""
    
    
import os
folder_path = 'data\movie'
files =[]

with os.scandir(folder_path) as entries:
  for entry in entries:
    if entry.is_file():  
    #   print(entry.name)
        files.append(entry.name)
    
for file in files:
    with open(rf"{folder_path}\{file}", 'r', errors='ignore') as f:
        html = f.read()
    print(extract_value(html))
# Out:
# Pulp Fiction (1994) - IMDb
# Se7en (1995) - IMDb
# Star Wars: Episode V - The Empire Strikes Back (1980) - IMDb
# Schindler's List (1993) - IMDb
# Memento (2000) - IMDb
# Batman Begins (2005) - IMDb
# Sin City (2005) - IMDb
# Braveheart (1995) - IMDb
# Titanic (1997) - IMDb
# Inception (2010) - IMDb
# 300 (2006) - IMDb
# Eternal Sunshine of the Spotless Mind (2004) - IMDb
# Reservoir Dogs (1992) - IMDb
# Donnie Darko (2001) - IMDb
# The Professional (1994) - IMDb
# Transformers (2007) - IMDb
# Requiem for a Dream (2000) - IMDb
# Kill Bill: Vol. 2 (2004) - IMDb
# Alien (1979) - IMDb
# Slumdog Millionaire (2008) - IMDb
# Iron Man (2008) - IMDb
# Casino Royale (2006) - IMDb
# The Incredibles (2004) - IMDb
# Children of Men (2006) - IMDb
# The Truman Show (1998) - IMDb
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964) - IMDb
# I Am Legend (2007) - IMDb
# Jurassic Park (1993) - IMDb
# Little Miss Sunshine (2006) - IMDb
# The Bourne Ultimatum (2007) - IMDb
# ...

# %%
print(len(html))
# Out:
# 1327155

# %%
html = """ 
<div class="card-information">
                     <span class="visually-hidden">
                      Vendor:
                     </span>
                     <div class="caption-with-letter-spacing light">
                      Uncle Don JM
                     </div>
                     <span class="caption-large light">
                     </span>
                     <div class="alireviews-review-star-rating" product-handle="graffiti-casual-loose-ragged-flare-pants-for-men-streetwear-wide-leg-jeans" product-id="8193364852972">
                     </div>
                     <div class="price price--on-sale">
                      <div class="price__container">
                       <div class="price__regular">
                        <span class="visually-hidden visually-hidden--inline">
                         Regular price
                        </span>
                        <span class="price-item price-item--regular">
                         <span class="money conversion-bear-money">
                          $86.00 USD
                         </span>
                        </span>
                       </div>
                       <div class="price__sale">
                        <span class="visually-hidden visually-hidden--inline">
                         Regular price
                        </span>
                        <span>
                         <s class="price-item price-item--regular">
                          <span class="money conversion-bear-money">
                           $90.16 USD
                          </span>
                         </s>
                        </span>
                        <span class="visually-hidden visually-hidden--inline">
                         Sale price
                        </span>
                        <span class="price-item price-item--sale price-item--last">
                         <span class="money conversion-bear-money">
                          $86.00 USD
                         </span>
                        </span>
                       </div>
                       <small class="unit-price caption hidden">
                        <span class="visually-hidden">
                         Unit price
                        </span>
                        <span class="price-item price-item--last">
                         <span>
                         </span>
                         <span aria-hidden="true">
                          /
                         </span>
                         <span class="visually-hidden">
                          per
                         </span>
                         <span>
                         </span>
                        </span>
                       </small>
                      </div>
                     </div>
                    </div>
                   </div>
                   <div class="card__badge bottom left">
                   </div>
                  </div>
                 </div>
                </div>
               </li>
               <li class="grid__item scroll-trigger animate--slide-in" data-cascade="" style="--animation-order: 10;">
                <link href="//eveyil.com/cdn/shop/t/46/assets/component-rating.css?v=157771854592137137841693891597" media="all" rel="stylesheet" type="text/css"/>
                <link href="//eveyil.com/cdn/shop/t/46/assets/component-volume-pricing.css?v=56284703641257077881693891597" media="all" rel="stylesheet" type="text/css"/>
                <div class="card-wrapper product-card-wrapper underline-links-hover">
                 <div class="card card--card card--media color-background-2 gradient" style="--ratio-percent: 100%;">
                  <div class="card__inner ratio" style="--ratio-percent: 100%;">
                   <div class="card__media">
                    <div class="media media--transparent media--hover-effect">
                     <img alt="44461973143788|44461973209324|44461973242092" class="motion-reduce" height="800" loading="lazy" sizes="(min-width: 1200px) 267px, (min-width: 990px) calc((100vw - 130px) / 4), (min-width: 750px) calc((100vw - 120px) / 3), calc((100vw - 35px) / 2)" src="//eveyil.com/cdn/shop/files/Sd80923cc581b40bfad6efb17cfb6d628C.webp?v=1708935503&amp;width=533" srcset="//eveyil.com/cdn/shop/files/Sd80923cc581b40bfad6efb17cfb6d628C.webp?v=1708935503&amp;width=165 165w,//eveyil.com/cdn/shop/files/Sd80923cc581b40bfad6efb17cfb6d628C.webp?v=1708935503&amp;width=360 360w,//eveyil.com/cdn/shop/files/Sd80923cc581b40bfad6efb17cfb6d628C.webp?v=1708935503&amp;width=533 533w,//eveyil.com/cdn/shop/files/Sd80923cc581b40bfad6efb17cfb6d628C.webp?v=1708935503&amp;width=720 720w,//eveyil.com/cdn/shop/files/Sd80923cc581b40bfad6efb17cfb6d628C.webp?v=1708935503 800w
                " width="800"/>
                     <img alt="" class="motion-reduce" height="800" loading="lazy" sizes="(min-width: 1200px) 267px, (min-width: 990px) calc((100vw - 130px) / 4), (min-width: 750px) calc((100vw - 120px) / 3), calc((100vw - 35px) / 2)" src="//eveyil.com/cdn/shop/files/Scc24b32443e442b4b84e893f2626fbabH.webp?v=1708935503&amp;width=533" srcset="//eveyil.com/cdn/shop/files/Scc24b32443e442b4b84e893f2626fbabH.webp?v=1708935503&amp;width=165 165w,//eveyil.com/cdn/shop/files/Scc24b32443e442b4b84e893f2626fbabH.webp?v=1708935503&amp;width=360 360w,//eveyil.com/cdn/shop/files/Scc24b32443e442b4b84e893f2626fbabH.webp?v=1708935503&amp;width=533 533w,//eveyil.com/cdn/shop/files/Scc24b32443e442b4b84e893f2626fbabH.webp?v=1708935503&amp;width=720 720w,//eveyil.com/cdn/shop/files/Scc24b32443e442b4b84e893f2626fbabH.webp?v=1708935503 800w
                  " width="800"/>
                    </div>
                   </div>
                   <div class="card__content">
                    <div class="card__information">
                     <h3 class="card__heading">
                      <a aria-labelledby="StandardCardNoMediaLink-template--16785467834604__product-grid-8193352827116 NoMediaStandardBadge-template--16785467834604__product-grid-8193352827116" class="full-unstyled-link" href="/products/inflation-streetwear-luminous-printing-t-shirt-for-men-oversized-glow-in-the-dark-black-hip-hop-tees" id="StandardCardNoMediaLink-template--16785467834604__product-grid-8193352827116">
                       INFLATION Luminous Wing Graphic Oversized T-shirt
                      </a>
                     </h3>
                    </div>
                    <div class="card__badge bottom left">
                    </div>
                   </div>
                  </div>
                  <div class="card__content">
                   <div class="card__information">
                    <h3 class="card__heading h5" id="title-template--16785467834604__product-grid-8193352827116">
                     <a aria-labelledby="CardLink-template--16785467834604__product-grid-8193352827116 Badge-template--16785467834604__product-grid-8193352827116" class="full-unstyled-link" href="/products/inflation-streetwear-luminous-printing-t-shirt-for-men-oversized-glow-in-the-dark-black-hip-hop-tees" id="CardLink-template--16785467834604__product-grid-8193352827116">
                      INFLATION Luminous Wing Graphic Oversized T-shirt
                     </a>
                    </h3>
                    <div class="card-information">
                     <span class="visually-hidden">
                      Vendor:
                     </span>
                     <div class="caption-with-letter-spacing light">
                      Inflation
                     </div>
                     <span class="caption-large light">
                     </span>
                     <div class="alireviews-review-star-rating" product-handle="inflation-streetwear-luminous-printing-t-shirt-for-men-oversized-glow-in-the-dark-black-hip-hop-tees" product-id="8193352827116">
                     </div>
                     <div class="price price--on-sale">
                      <div class="price__container">
                       <div class="price__regular">
                        <span class="visually-hidden visually-hidden--inline">
                         Regular price
                        </span>
                        <span class="price-item price-item--regular">
                         <span class="money conversion-bear-money">
                          $44.00 USD
                         </span>
                        </span>
                       </div>
                       <div class="price__sale">
                        <span class="visually-hidden visually-hidden--inline">
                         Regular price
                        </span>
                        <span>
                         <s class="price-item price-item--regular">
                          <span class="money conversion-bear-money">
                           $70.69 USD
                          </span>
                         </s>
                        </span>
                        <span class="visually-hidden visually-hidden--inline">
                         Sale price
                        </span>
                        <span class="price-item price-item--sale price-item--last">
                         <span class="money conversion-bear-money">
                          $44.00 USD
                         </span>
                        </span>
                       </div>
                       <small class="unit-price caption hidden">
                        <span class="visually-hidden">
                         Unit price
                        </span>
                        <span class="price-item price-item--last">
                         <span>
                         </span>
                         <span aria-hidden="true">
                          /
                         </span>
                         <span class="visually-hidden">
                          per
                         </span>
                         <span>
                         </span>
                        </span>
                       </small>
                      </div>
                     </div>
                    </div>
                   </div>
                   <div class="card__badge bottom left">
                   </div>
                  </div>
                 </div>
                </div>
               </li>
               <li class="grid__item scroll-trigger animate--slide-in" data-cascade="" style="--animation-order: 11;">
                <link href="//eveyil.com/cdn/shop/t/46/assets/component-rating.css?v=157771854592137137841693891597" media="all" rel="stylesheet" type="text/css"/>
                <link href="//eveyil.com/cdn/shop/t/46/assets/component-volume-pricing.css?v=56284703641257077881693891597" media="all" rel="stylesheet" type="text/css"/>
                <div class="card-wrapper product-card-wrapper underline-links-hover">
                 <div class="card card--card card--media color-background-2 gradient" style="--ratio-percent: 100%;">
                  <div class="card__inner ratio" style="--ratio-percent: 100%;">
                   <div class="card__media">
                    <div class="media media--transparent media--hover-effect">
                     <img alt="R69 Shirt" class="motion-reduce" height="1000" loading="lazy" sizes="(min-width: 1200px) 267px, (min-width: 990px) calc((100vw - 130px) / 4), (min-width: 750px) calc((100vw - 120px) / 3), calc((100vw - 35px) / 2)" src="//eveyil.com/cdn/shop/files/Sc27ab52caa4641be8903efdba05781cbu.jpg?v=1695017608&amp;width=533" srcset="//eveyil.com/cdn/shop/files/Sc27ab52caa4641be8903efdba05781cbu.jpg?v=1695017608&amp;width=165 165w,//eveyil.com/cdn/shop/files/Sc27ab52caa4641be8903efdba05781cbu.jpg?v=1695017608&amp;width=360 360w,//eveyil.com/cdn/shop/files/Sc27ab52caa4641be8903efdba05781cbu.jpg?v=1695017608&amp;width=533 533w,//eveyil.com/cdn/shop/files/Sc27ab52caa4641be8903efdba05781cbu.jpg?v=1695017608&amp;width=720 720w,//eveyil.com/cdn/shop/files/Sc27ab52caa4641be8903efdba05781cbu.jpg?v=1695017608 750w
                " width="750"/>
                     <img alt="" class="motion-reduce" height="1000" loading="lazy" sizes="(min-width: 1200px) 267px, (min-width: 990px) calc((100vw - 130px) / 4), (min-width: 750px) calc((100vw - 120px) / 3), calc((100vw - 35px) / 2)" src="//eveyil.com/cdn/shop/files/S3307d8cc10a9412daa62a68799999064v.jpg?v=1695017609&amp;width=533" srcset="//eveyil.com/cdn/shop/files/S3307d8cc10a9412daa62a68799999064v.jpg?v=1695017609&amp;width=165 165w,//eveyil.com/cdn/shop/files/S3307d8cc10a9412daa62a68799999064v.jpg?v=1695017609&amp;width=360 360w,//eveyil.com/cdn/shop/files/S3307d8cc10a9412daa62a68799999064v.jpg?v=1695017609&amp;width=533 533w,//eveyil.com/cdn/shop/files/S3307d8cc10a9412daa62a68799999064v.jpg?v=1695017609&amp;width=720 720w,//eveyil.com/cdn/shop/files/S3307d8cc10a9412daa62a68799999064v.jpg?v=1695017609 750w
                  " width="750"/>
                    </div>
                   </div>
                   <div class="card__content">
                    <div class="card__information">
                     <h3 class="card__heading">
                      <a aria-labelledby="StandardCardNoMediaLink-template--16785467834604__product-grid-8011967725804 NoMediaStandardBadge-template--16785467834604__product-grid-8011967725804" class="full-unstyled-link" href="/products/r69-streetwear-shirt" id="StandardCardNoMediaLink-template--16785467834604__product-grid-8011967725804">
                       R69 Shirt
                      </a>
                     </h3>
                    </div>
                    <div class="card__badge bottom left">
                    </div>
                   </div>
                  </div>
                  <div class="card__content">
                   <div class="card__information">
                    <h3 class="card__heading h5" id="title-template--16785467834604__product-grid-8011967725804">
                     <a aria-labelledby="CardLink-template--16785467834604__product-grid-8011967725804 Badge-template--16785467834604__product-grid-8011967725804" class="full-unstyled-link" href="/products/r69-streetwear-shirt" id="CardLink-template--16785467834604__product-grid-8011967725804">
                      R69 Shirt
                     </a>
                    </h3>
                    <div class="card-information">
                     <span class="visually-hidden">
                      Vendor:
                     </span>
                     <div class="caption-with-letter-spacing light">
                      Made Extreme Black Air
                     </div>
                     <span class="caption-large light">
                     </span>
                     <div class="alireviews-review-star-rating" product-handle="r69-streetwear-shirt" product-id="8011967725804">
                     </div>
                     <div class="price price--on-sale">
                      <div class="price__container">
                       <div class="price__regular">
                        <span class="visually-hidden visually-hidden--inline">
                         Regular price
                        </span>
                        <span class="price-item price-item--regular">
                         <span class="money conversion-bear-money">
                          $93.00 USD
                         </span>
                        </span>
                       </div>
                       <div class="price__sale">
                        <span class="visually-hidden visually-hidden--inline">
                         Regular price
                        </span>
                        <span>
                         <s class="price-item price-item--regular">
                          <span class="money conversion-bear-money">
                           $123.62 USD
                          </span>
                         </s>
                        </span>
                        <span class="visually-hidden visually-hidden--inline">
                         Sale price
                        </span>
                        <span class="price-item price-item--sale price-item--last">
                         <span class="money conversion-bear-money">
                          $93.00 USD
                         </span>
                        </span>
                       </div>
                       <small class="unit-price caption hidden">
                        <span class="visually-hidden">
                         Unit price
                        </span>
                        <span class="price-item price-item--last">
                         <span>
                         </span>
                         <span aria-hidden="true">
                          /
                         </span>
                         <span class="visually-hidden">
                          per
                         </span>
                         <span>
                         </span>
                        </span>
                       </small>
                      </div>
                     </div>
                    </div>
                   </div>
                   <div class="card__badge bottom left">
                   </div>
                  </div>
                 </div>
                </div>
               </li>
               <li class="grid__item scroll-trigger animate--slide-in" data-cascade="" style="--animation-order: 12;">
                <link href="//eveyil.com/cdn/shop/t/46/assets/component-rating.css?v=157771854592137137841693891597" media="all" rel="stylesheet" type="text/css"/>
                <link href="//eveyil.com/cdn/shop/t/46/assets/component-volume-pricing.css?v=56284703641257077881693891597" media="all" rel="stylesheet" type="text/css"/>
                <div class="card-wrapper product-card-wrapper underline-links-hover">
                 <div class="card card--card card--media color-background-2 gradient" style="--ratio-percent: 100%;">
                  <div class="card__inner ratio" style="--ratio-percent: 100%;">
                   <div class="card__media">
                    <div class="media media--transparent media--hover-effect">
                     <img alt="INFLATION Ripped Wide Leg Baggy Denim Jeans" class="motion-reduce" height="800" loading="lazy" sizes="(min-width: 1200px) 267px, (min-width: 990px) calc((100vw - 130px) / 4), (min-width: 750px) calc((100vw - 120px) / 3), calc((100vw - 35px) / 2)" src="//eveyil.com/cdn/shop/products/Scf33c4d491244743a1909ecc6b7f60cbc.jpg?v=1692098828&amp;width=533" srcset="//eveyil.com/cdn/shop/products/Scf33c4d491244743a1909ecc6b7f60cbc.jpg?v=1692098828&amp;width=165 165w,//eveyil.com/cdn/shop/products/Scf33c4d491244743a1909ecc6b7f60cbc.jpg?v=1692098828&amp;width=360 360w,//eveyil.com/cdn/shop/products/Scf33c4d491244743a1909ecc6b7f60cbc.jpg?v=1692098828&amp;width=533 533w,//eveyil.com/cdn/shop/products/Scf33c4d491244743a1909ecc6b7f60cbc.jpg?v=1692098828&amp;width=720 720w,//eveyil.com/cdn/shop/products/Scf33c4d491244743a1909ecc6b7f60cbc.jpg?v=1692098828 800w
                " width="800"/>
                     <img alt="" class="motion-reduce" height="800" loading="lazy" sizes="(min-width: 1200px) 267px, (min-width: 990px) calc((100vw - 130px) / 4), (min-width: 750px) calc((100vw - 120px) / 3), calc((100vw - 35px) / 2)" src="//eveyil.com/cdn/shop/files/S730a256bef534174b76e642bc0159caex.jpg?v=1692119241&amp;width=533" srcset="//eveyil.com/cdn/shop/files/S730a256bef534174b76e642bc0159caex.jpg?v=1692119241&amp;width=165 165w,//eveyil.com/cdn/shop/files/S730a256bef534174b76e642bc0159caex.jpg?v=1692119241&amp;width=360 360w,//eveyil.com/cdn/shop/files/S730a256bef534174b76e642bc0159caex.jpg?v=1692119241&amp;width=533 533w,//eveyil.com/cdn/shop/files/S730a256bef534174b76e642bc0159caex.jpg?v=1692119241&amp;width=720 720w,//eveyil.com/cdn/shop/files/S730a256bef534174b76e642bc0159caex.jpg?v=1692119241 800w
                  " width="800"/>
                    </div>
                   </div>
                   <div class="card__content">
                    <div class="card__information">
                     <h3 class="card__heading">
                      <a aria-labelledby="StandardCardNoMediaLink-template--16785467834604__product-grid-7963188101356 NoMediaStandardBadge-template--16785467834604__product-grid-7963188101356" class="full-unstyled-link" href="/products/inflation-street-style-washed-ripped-wide-leg-jeans-men-hip-hop-baggy-denim-trousers-plus-size" id="StandardCardNoMediaLink-template--16785467834604__product-grid-7963188101356">
                       INFLATION Ripped Wide Leg Baggy Denim Jeans
                      </a>
                     </h3>
                    </div>
                    <div class="card__badge bottom left">
                    </div>
                   </div>
                  </div>
                  <div class="card__content">
                   <div class="card__information">
                    <h3 class="card__heading h5" id="title-template--16785467834604__product-grid-7963188101356">
                     <a aria-labelledby="CardLink-template--16785467834604__product-grid-7963188101356 Badge-template--16785467834604__product-grid-7963188101356" class="full-unstyled-link" href="/products/inflation-street-style-washed-ripped-wide-leg-jeans-men-hip-hop-baggy-denim-trousers-plus-size" id="CardLink-template--16785467834604__product-grid-7963188101356">
                      INFLATION Ripped Wide Leg Baggy Denim Jeans
                     </a>
                    </h3>
                    <div class="card-information">
                     <span class="visually-hidden">
                      Vendor:
                     </span>
                     <div class="caption-with-letter-spacing light">
                      Inflation
                     </div>
                     <span class="caption-large light">
                     </span>
                     <div class="alireviews-review-star-rating" product-handle="inflation-street-style-washed-ripped-wide-leg-jeans-men-hip-hop-baggy-denim-trousers-plus-size" product-id="7963188101356">
                     </div>
                     <div class="price price--sold-out price--on-sale">
                      <div class="price__container">
                       <div class="price__regular">
                        <span class="visually-hidden visually-hidden--inline">
                         Regular price
                        </span>
                        <span class="price-item price-item--regular">
                         <span class="money conversion-bear-money">
                          $63.00 USD
                         </span>
                        </span>
                       </div>
                       <div class="price__sale">
                        <span class="visually-hidden visually-hidden--inline">
                         Regular price
                        </span>
                        <span>
                         <s class="price-item price-item--regular">
                          <span class="money conversion-bear-money">
                           $88.06 USD
                          </span>
                         </s>
                        </span>
                        <span class="visually-hidden visually-hidden--inline">
                         Sale price
                        </span>
                        <span class="price-item price-item--sale price-item--last">
                         <span class="money conversion-bear-money">
                          $63.00 USD
                         </span>
                        </span>
                       </div>
                       <small class="unit-price caption hidden">
                        <span class="visually-hidden">
                         Unit price
                        </span>
                        <span class="price-item price-item--last">
                         <span>
                         </span>
                         <span aria-hidden="true">
                          /
                         </span>
                         <span class="visually-hidden">
                          per
                         </span>
                         <span>
                         </span>
                        </span>
                       </small>
                      </div>
                     </div>
                    </div>
                   </div>
                   <div class="card__badge bottom left">
                   </div>
                  </div>
                 </div>
                </div>
               </li>
               <li class="grid__item scroll-trigger animate--slide-in" data-cascade="" style="--animation-order: 13;">
                <link href="//eveyil.com/cdn/shop/t/46/assets/component-rating.css?v=157771854592137137841693891597" media="all" rel="stylesheet" type="text/css"/>
                <link href="//eveyil.com/cdn/shop/t/46/assets/component-volume-pricing.css?v=56284703641257077881693891597" media="all" rel="stylesheet" type="text/css"/>
                <div class="card-wrapper product-card-wrapper underline-links-hover">
                 <div class="card card--card card--media color-background-2 gradient" style="--ratio-percent: 100%;">
                  <div class="card__inner ratio" style="--ratio-percent: 100%;">
                   <div class="card__media">
                    <div class="media media--transparent media--hover-effect">
                     <img alt="INFALTION Ripped Oversized Knit Sweater Unisex" class="motion-reduce" height="800" loading="lazy" sizes="(min-width: 1200px) 267px, (min-width: 990px) calc((100vw - 130px) / 4), (min-width: 750px) calc((100vw - 120px) / 3), calc((100vw - 35px) / 2)" src="//eveyil.com/cdn/shop/products/S271b23bd72514805b3163067a7a7b114G.jpg?v=1691575308&amp;width=533" srcset="//eveyil.com/cdn/shop/products/S271b23bd72514805b3163067a7a7b114G.jpg?v=1691575308&amp;width=165 165w,//eveyil.com/cdn/shop/products/S271b23bd72514805b3163067a7a7b114G.jpg?v=1691575308&amp;width=360 360w,//eveyil.com/cdn/shop/products/S271b23bd72514805b3163067a7a7b114G.jpg?v=1691575308&amp;width=533 533w,//eveyil.com/cdn/shop/products/S271b23bd72514805b3163067a7a7b114G.jpg?v=1691575308&amp;width=720 720w,//eveyil.com/cdn/shop/products/S271b23bd72514805b3163067a7a7b114G.jpg?v=1691575308 800w
                " width="800"/>
                     <img alt="" class="motion-reduce" height="800" loading="lazy" sizes="(min-width: 1200px) 267px, (min-width: 990px) calc((100vw - 130px) / 4), (min-width: 750px) calc((100vw - 120px) / 3), calc((100vw - 35px) / 2)" src="//eveyil.com/cdn/shop/files/Sd5a8921d891f4a6e8240097c9f69c91af.jpg?v=1691575311&amp;width=533" srcset="//eveyil.com/cdn/shop/files/Sd5a8921d891f4a6e8240097c9f69c91af.jpg?v=1691575311&amp;width=165 165w,//eveyil.com/cdn/shop/files/Sd5a8921d891f4a6e8240097c9f69c91af.jpg?v=1691575311&amp;width=360 360w,//eveyil.com/cdn/shop/files/Sd5a8921d891f4a6e8240097c9f69c91af.jpg?v=1691575311&amp;width=533 533w,//eveyil.com/cdn/shop/files/Sd5a8921d891f4a6e8240097c9f69c91af.jpg?v=1691575311&amp;width=720 720w,//eveyil.com/cdn/shop/files/Sd5a8921d891f4a6e8240097c9f69c91af.jpg?v=1691575311 800w
                  " width="800"/>
                    </div>
                   </div>
                   <div class="card__content">
                    <div class="card__information">
                     <h3 class="card__heading">
                      <a aria-labelledby="StandardCardNoMediaLink-template--16785467834604__product-grid-7960709497068 NoMediaStandardBadge-template--16785467834604__product-grid-7960709497068" class="full-unstyled-link" href="/products/infaltion-streetwear-ripped-hip-hop-sweaters-men-2023-autumn-new-trendy-oversized-knit-pullovers-unisex" id="StandardCardNoMediaLink-template--16785467834604__product-grid-7960709497068">
                       INFALTION Ripped Oversized Knit Sweater Unisex
                      </a>
                     </h3>
                    </div>
                    <div class="card__badge bottom left">
                    </div>
                   </div>
                  </div>
                  <div class="card__content">
                   <div class="card__information">
                    <h3 class="card__heading h5" id="title-template--16785467834604__product-grid-7960709497068">
                     <a aria-labelledby="CardLink-template--16785467834604__product-grid-7960709497068 Badge-template--16785467834604__product-grid-7960709497068" class="full-unstyled-link" href="/products/infaltion-streetwear-ripped-hip-hop-sweaters-men-2023-autumn-new-trendy-oversized-knit-pullovers-unisex" id="CardLink-template--16785467834604__product-grid-7960709497068">
                      INFALTION Ripped Oversized Knit Sweater Unisex
                     </a>
                    </h3>
                    <div class="card-information">
                     <span class="visually-hidden">
                      Vendor:
                     </span>
                     <div class="caption-with-letter-spacing light">
                      Inflation
                     </div>
                     <span class="caption-large light">
                     </span>
                     <div class="alireviews-review-star-rating" product-handle="infaltion-streetwear-ripped-hip-hop-sweaters-men-2023-autumn-new-trendy-oversized-knit-pullovers-unisex" product-id="7960709497068">
                     </div>
                     <div class="price price--on-sale">
                      <div class="price__container">
                       <div class="price__regular">
                        <span class="visually-hidden visually-hidden--inline">
                         Regular price
                        </span>
                        <span class="price-item price-item--regular">
                         <span class="money conversion-bear-money">
                          $48.00 USD
                         </span>
                        </span>
                       </div>
                       <div class="price__sale">
                        <span class="visually-hidden visually-hidden--inline">
                         Regular price
                        </span>
                        <span>
                         <s class="price-item price-item--regular">
                          <span class="money conversion-bear-money">
                           $79.31 USD
                          </span>
                         </s>
                        </span>
                        <span class="visually-hidden visually-hidden--inline">
                         Sale price
                        </span>
                        <span class="price-item price-item--sale price-item--last">
                         <span class="money conversion-bear-money">
                          $48.00 USD
                         </span>
                        </span>
                       </div>
                       <small class="unit-price caption hidden">
                        <span class="visually-hidden">
                         Unit price
                        </span>
                        <span class="price-item price-item--last">
                         <span>
                         </span>
                         <span aria-hidden="true">
                          /
                         </span>
                         <span class="visually-hidden">
                          per
                         </span>
                         <span>
                         </span>
                        </span>
                       </small>
                      </div>
                     </div>
                    </div>
                   </div>
                   <div class="card__badge bottom left">
                   </div>
                  </div>
                 </div>
                </div>
               </li>
               <li class="grid__item scroll-trigger animate--slide-in" data-cascade="" style="--animation-order: 14;">
                <link href="//eveyil.com/cdn/shop/t/46/assets/component-rating.css?v=157771854592137137841693891597" media="all" rel="stylesheet" type="text/css"/>
                <link href="//eveyil.com/cdn/shop/t/46/assets/component-volume-pricing.css?v=56284703641257077881693891597" media="all" rel="stylesheet" type="text/css"/>
                <div class="card-wrapper product-card-wrapper underline-links-hover">
                 <div class="card card--card card--media color-background-2 gradient" style="--ratio-percent: 100%;">
                  <div class="card__inner ratio" style="--ratio-percent: 100%;">
                   <div class="card__media">
                    <div class="media media--transparent media--hover-effect">
                     <img alt="Growing In The World Embroidered Suede Short-sleeved T-Shirt" class="motion-reduce" height="1500" loading="lazy" sizes="(min-width: 1200px) 267px, (min-width: 990px) calc((100vw - 130px) / 4), (min-width: 750px) calc((100vw - 120px) / 3), calc((100vw - 35px) / 2)" src="//eveyil.com/cdn/shop/products/S83e816ddad0740ab98d39592a1f2bc7cg.jpg?v=1686831870&amp;width=533" srcset="//eveyil.com/cdn/shop/products/S83e816ddad0740ab98d39592a1f2bc7cg.jpg?v=1686831870&amp;width=165 165w,//eveyil.com/cdn/shop/products/S83e816ddad0740ab98d39592a1f2bc7cg.jpg?v=1686831870&amp;width=360 360w,//eveyil.com/cdn/shop/products/S83e816ddad0740ab98d39592a1f2bc7cg.jpg?v=1686831870&amp;width=533 533w,//eveyil.com/cdn/shop/products/S83e816ddad0740ab98d39592a1f2bc7cg.jpg?v=1686831870&amp;width=720 720w,//eveyil.com/cdn/shop/products/S83e816ddad0740ab98d39592a1f2bc7cg.jpg?v=1686831870&amp;width=940 940w,//eveyil.com/cdn/shop/products/S83e816ddad0740ab98d39592a1f2bc7cg.jpg?v=1686831870&amp;width=1066 1066w,//eveyil.com/cdn/shop/products/S83e816ddad0740ab98d39592a1f2bc7cg.jpg?v=1686831870 1500w
                " width="1500"/>
                     <img alt="" class="motion-reduce" height="1500" loading="lazy" sizes="(min-width: 1200px) 267px, (min-width: 990px) calc((100vw - 130px) / 4), (min-width: 750px) calc((100vw - 120px) / 3), calc((100vw - 35px) / 2)" src="//eveyil.com/cdn/shop/files/S0202ba9bdaf948ecb061e97e21d042efW.jpg?v=1692282742&amp;width=533" srcset="//eveyil.com/cdn/shop/files/S0202ba9bdaf948ecb061e97e21d042efW.jpg?v=1692282742&amp;width=165 165w,//eveyil.com/cdn/shop/files/S0202ba9bdaf948ecb061e97e21d042efW.jpg?v=1692282742&amp;width=360 360w,//eveyil.com/cdn/shop/files/S0202ba9bdaf948ecb061e97e21d042efW.jpg?v=1692282742&amp;width=533 533w,//eveyil.com/cdn/shop/files/S0202ba9bdaf948ecb061e97e21d042efW.jpg?v=1692282742&amp;width=720 720w,//eveyil.com/cdn/shop/files/S0202ba9bdaf948ecb061e97e21d042efW.jpg?v=1692282742&amp;width=940 940w,//eveyil.com/cdn/shop/files/S0202ba9bdaf948ecb061e97e21d042efW.jpg?v=1692282742&amp;width=1066 1066w,//eveyil.com/cdn/shop/files/S0202ba9bdaf948ecb061e97e21d042efW.jpg?v=1692282742 1500w
                  " width="1500"/>
                    </div>
                   </div>
                   <div class="card__content">
                    <div class="card__information">
                     <h3 class="card__heading">
                      <a aria-labelledby="StandardCardNoMediaLink-template--16785467834604__product-grid-7935410569452 NoMediaStandardBadge-template--16785467834604__product-grid-7935410569452" class="full-unstyled-link" href="/products/embroidered-suede-short-sleeved-t-shirt-men-39-s-summer-high-street-american-casual-t-shirt-streetwear-vintage-t-shirt-unisex" id="StandardCardNoMediaLink-template--16785467834604__product-grid-7935410569452">
                       Growing In The World Embroidered Suede Short-sleeved T-Shirt
                      </a>
                     </h3>
                    </div>
                    <div class="card__badge bottom left">
                    </div>
                   </div>
                  </div>
                  <div class="card__content">
                   <div class="card__information">
                    <h3 class="card__heading h5" id="title-template--16785467834604__product-grid-7935410569452">
                     <a aria-labelledby="CardLink-template--16785467834604__product-grid-7935410569452 Badge-template--16785467834604__product-grid-7935410569452" class="full-unstyled-link" href="/products/embroidered-suede-short-sleeved-t-shirt-men-39-s-summer-high-street-american-casual-t-shirt-streetwear-vintage-t-shirt-unisex" id="CardLink-template--16785467834604__product-grid-7935410569452">
                      Growing In The World Embroidered Suede Short-sleeved T-Shirt
                     </a>
                    </h3>
                    <div class="card-information">
                     <span class="visually-hidden">
                      Vendor:
                     </span>
                     <div class="caption-with-letter-spacing light">
                      Uncle Don JM
                     </div>
                     <span class="caption-large light">
                     </span>
                     <div class="alireviews-review-star-rating" product-handle="embroidered-suede-short-sleeved-t-shirt-men-39-s-summer-high-street-american-casual-t-shirt-streetwear-vintage-t-shirt-unisex" product-id="7935410569452">
                     </div>
                     <div class="price price--on-sale">
                      <div class="price__container">
                       <div class="price__regular">
                        <span class="visually-hidden visually-hidden--inline">
                         Regular price
                        </span>
                        <span class="price-item price-item--regular">
                         <span class="money conversion-bear-money">
                          $46.00 USD
                         </span>
                        </span>
                       </div>
                       <div class="price__sale">
                        <span class="visually-hidden visually-hidden--inline">
                         Regular price
                        </span>
                        <span>
                         <s class="price-item price-item--regular">
                          <span class="money conversion-bear-money">
                           $78.39 USD
                          </span>
                         </s>
                        </span>
                        <span class="visually-hidden visually-hidden--inline">
                         Sale price
                        </span>
                        <span class="price-item price-item--sale price-item--last">
                         <span class="money conversion-bear-money">
                          $46.00 USD
                         </span>
                        </span>
                       </div>
                       <small class="unit-price caption hidden">
                        <span class="visually-hidden">
                         Unit price
                        </span>
                        <span class="price-item price-item--last">
                         <span>
                         </span>
                         <span aria-hidden="true">
                          /
                         </span>
                         <span class="visually-hidden">
                          per
                         </span>
                         <span>
                         </span>
                        </span>
                       </small>
                      </div>
                     </div>
                    </div>
                   </div>
                   <div class="card__badge bottom left">
                   </div>
                  </div>
                 </div>
"""

# %%
print(coder(htmlcode=html, instructions="find price of all the items on website hint: check you can get from class price-item price-item--regular"))
# Out:
#  ```python
#     import bs4
#     import re
#     def extract_value(HTML):
#         soup = bs4.BeautifulSoup(HTML, 'lxml')
#
#         raw_price = soup.findAll('span', attrs={"class":"money conversion-bear-money"})
#
#         prices = []
#         for element in raw_price:
#             prices.append(element.text.strip())
#
#         return prices
#
#     print(extract_value(html))
#  ```

# %%
import bs4
import re
def extract_value(HTML):
    soup = bs4.BeautifulSoup(HTML, 'lxml')

    raw_price = soup.findAll('span', attrs={"class":"money conversion-bear-money"})

    prices = []
    for element in raw_price:
        prices.append(element.text.strip())

    return prices

print(extract_value(html))
# Out:
# ['$86.00 USD', '$90.16 USD', '$86.00 USD', '$44.00 USD', '$70.69 USD', '$44.00 USD', '$93.00 USD', '$123.62 USD', '$93.00 USD', '$63.00 USD', '$88.06 USD', '$63.00 USD', '$48.00 USD', '$79.31 USD', '$48.00 USD', '$46.00 USD', '$78.39 USD', '$46.00 USD']

# %%
import requests
from bs4 import BeautifulSoup

url = "https://eveyil.com/collections/trending-now"

response = requests.get(url)

if response.status_code == 200:
  # Parse the HTML content
  soup = BeautifulSoup(response.content, 'html.parser')
  web_html = soup.prettify()
  # Print the HTML source code
  print(soup.prettify())
else:
  print("Error retrieving the website:", response.status_code)
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en">
#  <style>
#   .price__sale s.price-item.price-item--regular {
# display:none;
# }
#  </style>
#  <head>
#   <meta content="3c53bfe71659144cd13ffa1cd0c5804c" name="p:domain_verify"/>
#   <!-- Google tag (gtag.js) -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-2PZZV9RV66">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || []; function gtag(){dataLayer.push(arguments);} gtag('js', new Date()); gtag('config', 'G-2PZZV9RV66');
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="" name="theme-color"/>
#   <link href="https://eveyil.com/collections/trending-now" rel="canonical"/>
# ...

# %%
print(extract_value(web_html))
# Out:
# ['$0.00 USD', '$81.00 USD', '$89.93 USD', '$81.00 USD', '$62.00 USD', '$78.17 USD', '$62.00 USD', '$49.99 USD', '$73.37 USD', '$49.99 USD', '$71.00 USD', '$83.31 USD', '$71.00 USD', '$54.00 USD', '$74.92 USD', '$54.00 USD', '$48.00 USD', '$72.86 USD', '$48.00 USD', '$69.99 USD', '$82.16 USD', '$69.99 USD', '$84.00 USD', '$89.12 USD', '$84.00 USD', '$86.00 USD', '$90.16 USD', '$86.00 USD', '$44.00 USD', '$70.69 USD', '$44.00 USD', '$93.00 USD', '$123.62 USD', '$93.00 USD', '$63.00 USD', '$88.06 USD', '$63.00 USD', '$48.00 USD', '$79.31 USD', '$48.00 USD', '$46.00 USD', '$78.39 USD', '$46.00 USD', '$41.00 USD', '$76.66 USD', '$41.00 USD', '$68.00 USD', '$94.91 USD', '$68.00 USD', '$58.00 USD', '$99.98 USD', '$58.00 USD', '$63.00 USD', '$97.43 USD', '$63.00 USD', '$43.00 USD', '$78.63 USD', '$43.00 USD', '$62.00 USD', '$93.04 USD', '$62.00 USD', '$65.00 USD', '$93.89 USD', '$65.00 USD', '$61.00 USD', '$98.11 USD', '$61.00 USD', '$43.00 USD', '$78.18 USD', '$43.00 USD', '$43.00 USD', '$8
# ...
